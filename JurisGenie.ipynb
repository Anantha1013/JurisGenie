# %% [markdown]
# **Complete document attack**

# %%
# !pip install semantic-router
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import os
from getpass import getpass
from semantic_router.encoders import OpenAIEncoder

os.environ["OPENAI_API_KEY"] = "sk-cwhrevvnfTqr3brtfyUF5UconAt8XLu2BQ3dRYT5WmT3BlbkFJvnhu9ApmWmd4uck4qhn9CQ1rTwJ8pJQMTv8i1iTjUA"

encoder = OpenAIEncoder(name="text-embedding-3-small")

# %%
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
# File path on Google Drive
file_path = '/content/drive/MyDrive/JurisGenie/large_scraped_data.txt'

# Open and read the file
with open(file_path, 'r', encoding='utf-8') as file:
    data = file.read()

# %%
from semantic_router.splitters import RollingWindowSplitter
from semantic_router.utils.logger import logger

logger.setLevel("WARNING")  # reduce logs from splitter

splitter = RollingWindowSplitter(
    encoder=encoder,
    dynamic_threshold=True,
    min_split_tokens=100,
    max_split_tokens=500,
    window_size=2,
    plot_splits=True,  # set this to true to visualize chunking
    enable_statistics=True  # to print chunking stats
)

# %%
splits = splitter([data])
# Out:
# 2024-10-25 05:52:43 WARNING semantic_router.utils.logger Retrying in 2 seconds...
# 2024-10-25 05:52:49 WARNING semantic_router.utils.logger Retrying in 4 seconds...
# 2024-10-25 05:52:59 WARNING semantic_router.utils.logger Retrying in 8 seconds...
# 2024-10-25 05:53:17 WARNING semantic_router.utils.logger Retrying in 16 seconds...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/semantic_router/encoders/openai.py in __call__(self, docs, truncate)
#      89             try:
# ---> 90                 embeds = self.client.embeddings.create(
#      91                     input=docs,
#
# /usr/local/lib/python3.10/dist-packages/openai/resources/embeddings.py in create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     123
# --> 124         return self._post(
# ...

# %%
# !pip install langchain_huggingface

# %%
from langchain_huggingface import HuggingFaceEmbeddings

model_name = "sentence-transformers/all-mpnet-base-v2"
model_kwargs = {'device': 'cpu'}
# model_kwargs = {'device': 'cuda'}
encode_kwargs = {'normalize_embeddings': False}
hf_embeddings = HuggingFaceEmbeddings(
        model_name=model_name,
        model_kwargs=model_kwargs,
        encode_kwargs=encode_kwargs,
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# ...

# %%
# !pip install langchain_experimental

# %%
from langchain_experimental.text_splitter import SemanticChunker
# from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_community.embeddings import HuggingFaceEmbeddings

# text_splitter = SemanticChunker(OpenAIEmbeddings())
hf_embeddings = HuggingFaceEmbeddings()
text_splitter = SemanticChunker(hf_embeddings,)

docs = text_splitter.create_documents([data])
print(docs[0].page_content)
# Out:
# <ipython-input-23-898f819e5169>:6: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   hf_embeddings = HuggingFaceEmbeddings()
# Take notes as you read a judgment using ourVirtual Legal Assistantand get email alerts whenever a new judgment matches your query (Query Alert Service).

# %%
print(docs[1].page_content)
# Out:
# Try out ourPremium Member Services--Sign up todayand get free trial for one month.Dipak Misra, J. [for himself and Ashok Bhushan, J.]
#
# The cold evening of Delhi  on  16th  December,  2012  could  not  have  even
# remotely planted the feeling in the twenty-three  year  old  lady,  a  para-
# medical student, who had gone with her friend to watch a film at PVR  Select
# City Walk Mall, Saket, that in the  next  few  hours,  the  shattering  cold
# night that was gradually stepping in would bring  with  it  the  devastating
# hour of darkness when she, alongwith her friend, would get  into  a  bus  at
# Munirka bus stand to be dropped at a particular place;  and  possibly  could
# not have imagined that she would be a prey to the savage lust of a  gang  of
# six, face brutal assault and become a playful thing  that  could  be  tossed
# around at their wild whim and her private parts would be  ruptured  to  give
# ...

# %%
print(len(docs))
# Out:
# 158

# %%
'''from semantic_router.splitters import RollingWindowSplitter
from semantic_router.utils.logger import logger

logger.setLevel("WARNING")  # reduce logs from splitter

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
encoder = lambda texts: model.encode(texts, convert_to_tensor=False)

splitter = RollingWindowSplitter(
    encoder=encoder,
    dynamic_threshold=True,
    min_split_tokens=100,
    max_split_tokens=500,
    window_size=2,
    plot_splits=True,  # set this to true to visualize chunking
    enable_statistics=True  # to print chunking stats
)


splits = splitter([data])'''
# Out:
# 'from semantic_router.splitters import RollingWindowSplitter\nfrom semantic_router.utils.logger import logger\n\nlogger.setLevel("WARNING")  # reduce logs from splitter\n\nmodel = SentenceTransformer(\'sentence-transformers/all-MiniLM-L6-v2\')\nencoder = lambda texts: model.encode(texts, convert_to_tensor=False)\n\nsplitter = RollingWindowSplitter(\n    encoder=encoder,\n    dynamic_threshold=True,\n    min_split_tokens=100,\n    max_split_tokens=500,\n    window_size=2,\n    plot_splits=True,  # set this to true to visualize chunking\n    enable_statistics=True  # to print chunking stats\n)\n\n\nsplits = splitter([data])'

# %%
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.8/255.8 kB 3.9 MB/s eta 0:00:00
# ...

# %%
for i in embeddings:
  print(i)
  break
# Out:
# [ 1.78327281e-02  3.06269005e-02 -7.43744820e-02 -1.52883511e-02
#   8.40612594e-03  2.35923417e-02  1.01968579e-01  1.28466794e-02
#   7.15889037e-02  2.39656176e-02 -1.55088734e-02 -7.83371106e-02
#   3.98026593e-02  1.02410987e-02 -4.72891591e-02  6.08590655e-02
#   7.18607232e-02 -4.24383394e-02 -3.28113101e-02 -5.10892738e-03
#   4.70750174e-03  5.25425002e-02 -1.40864756e-02 -2.31916811e-02
#  -1.12214787e-02 -5.71069345e-02 -8.02634563e-03 -6.48933405e-04
#  -1.85836870e-02 -5.73435165e-02 -1.91368256e-02  6.39940333e-03
#   7.02869473e-03  5.31871133e-02  7.21285213e-03 -6.33439124e-02
#   3.70091982e-02 -3.67455296e-02 -2.30171327e-02 -5.85414357e-02
#  -1.52742695e-02 -1.70229338e-02 -2.60347258e-02  6.50351460e-04
#  -6.02152525e-03 -1.19721210e-02 -5.71351163e-02  3.43920998e-02
#  -4.36306372e-02  3.13782394e-02 -8.15309957e-02 -1.18508883e-01
#   3.63489725e-02  3.15685757e-02 -2.01276671e-02  4.34614308e-02
# ...

# %%
import numpy as np

# Normalize embeddings
def normalize_embeddings(embeddings):
    return embeddings / np.linalg.norm(embeddings, axis=1, keepdims=True)

# %%
# !pip install sklearn.decomposition
# Out:
# ERROR: Could not find a version that satisfies the requirement sklearn.decomposition (from versions: none)
# ERROR: No matching distribution found for sklearn.decomposition

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Check the shape of your embedding matrix
#print("Shape of embedding_matrix:", embedding_matrix.shape)

# If you only have one sample, PCA with n_components=2 won't work
# You can either add more samples or reduce n_components to 1

# Option 1: Reduce n_components to 1 (if you only have one sample)
if embedding_matrix.shape[0] == 1:
    pca = PCA(n_components=1)
else:
    pca = PCA(n_components=2)

# Apply PCA
reduced_embeddings = pca.fit_transform(embedding_matrix)

# Plot the PCA result (adjust based on n_components)
plt.figure(figsize=(8, 6))

if embedding_matrix.shape[0] == 1:
    # If n_components=1, plot a single point
    plt.scatter(reduced_embeddings[0], 0, c='blue', edgecolor='k', s=50) # Plotting against 0 on y-axis
else:
    # If n_components=2, plot as before
    plt.scatter(reduced_embeddings[:, 0], reduced_embeddings[:, 1], c='blue', edgecolor='k', s=50)
    for i in range(len(reduced_embeddings)):
        plt.text(reduced_embeddings[i, 0], reduced_embeddings[i, 1], str(i), fontsize=9)

plt.title("PCA Visualization of Embedding Matrix")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2") # Adjust label if n_components=1
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-2d55cd90b0cc> in <cell line: 12>()
#      10 # Apply PCA to reduce the dimensionality to 2 components
#      11 pca = PCA(n_components=2)
# ---> 12 reduced_embeddings = pca.fit_transform(embedding_matrix)
#      13
#      14 # Plot the 2D PCA result
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# ...

# %%
# !pip install qdrant-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.4/266.4 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 87.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
# ...

# %%
client.get_collection("{collection_name}")
# Out:
# CollectionInfo(status=<CollectionStatus.GREEN: 'green'>, optimizer_status=<OptimizersStatusOneOf.OK: 'ok'>, vectors_count=None, indexed_vectors_count=0, points_count=0, segments_count=2, config=CollectionConfig(params=CollectionParams(vectors=VectorParams(size=384, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None, datatype=None, multivector_config=None), shard_number=1, sharding_method=None, replication_factor=1, write_consistency_factor=1, read_fan_out_factor=None, on_disk_payload=True, sparse_vectors=None), hnsw_config=HnswConfig(m=16, ef_construct=100, full_scan_threshold=10000, max_indexing_threads=0, on_disk=False, payload_m=None), optimizer_config=OptimizersConfig(deleted_threshold=0.2, vacuum_min_vector_number=1000, default_segment_number=0, max_segment_size=None, memmap_threshold=None, indexing_threshold=20000, flush_interval_sec=5, max_optimization_threads=None), wal_config=WalConfig(wal_capacity_mb=32, wal_segments_ahead=0), qua
# ...

# %%
from qdrant_client import QdrantClient, models
client = QdrantClient(
    url="https://e1d547b9-71ad-4d06-a9b2-ebae2c43f740.us-east4-0.gcp.cloud.qdrant.io:6333",
    api_key="xK64v33giC5SIp2iUTPFKp5LUpzBVmomi3Fb-go3_2HX6LwK-V7ahg",
)

# %%
l=[]
for i in range(4):
  l.append(i)

print(l)

num=1
client.upsert(
    collection_name="star_charts",
    points=[
        models.PointStruct(
            id=num,
            payload={
                "type": "theft",
            },
            vector=l,
        ),
    ],
)
# Out:
# [0, 1, 2, 3]
# UpdateResult(operation_id=3, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
query_vector=[0.2, 0.1, 0.9, 0.7]
result = client.search(
    collection_name="star_charts",
    query_vector=query_vector,
    limit=2,
)
print(result)
# Out:
# [ScoredPoint(id=4, version=0, score=1.362, payload={'colony': 'Moon'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id=3, version=1, score=0.9099999, payload={'type': 'sexual assault'}, vector=None, shard_key=None, order_value=None)]

# %%
print(len(embeddings))
# Out:
# 158

# %%
for i in range(0,len(embeddings)):
  client.upsert(
      collection_name="Jurisgenie1",
      points=[
          models.PointStruct(
              id=i,
              vector=embeddings[i],
              payload={
                  "chunk":docs[i].page_content
              }
          )
      ]
  )

# %%
query="What happened on November 25 2016.It is related to some land dispute"
model = SentenceTransformer("all-MiniLM-L6-v2")


queryEmbeddings = model.encode(query)
print(queryEmbeddings)
# Out:
# [ 2.63282582e-02  7.27944970e-02  5.89113124e-02 -1.92050580e-02
#   5.33062108e-02 -7.02097416e-02 -7.49186873e-02 -6.62719458e-03
#  -7.53324777e-02  2.93256231e-02  3.39324540e-03  6.07696772e-02
#  -2.46966351e-02  7.02099800e-02 -5.51853068e-02  1.06181048e-01
#  -5.72526418e-02  1.39052728e-02 -1.02543220e-01  2.15291530e-02
#  -4.29126285e-02  5.19255595e-03 -7.91386962e-02 -4.27456647e-02
#   9.68285277e-03  6.60973117e-02 -1.39466743e-03 -2.40926538e-03
#  -1.50093483e-02  1.64658984e-03  5.93612827e-02  3.81895192e-02
#  -3.73539925e-02  3.67829315e-02  7.57769216e-03 -1.35684973e-02
#   1.74143165e-02 -4.57453094e-02  8.73142928e-02 -2.77697295e-02
#   3.15279514e-02 -9.38033834e-02  8.22355226e-02  1.30429355e-04
#  -4.58906317e-04  1.01914346e-01  2.58758441e-02  2.83560511e-02
#  -2.43484862e-02 -1.41680734e-02  7.44113103e-02  3.28064673e-02
#  -2.22530123e-02 -3.75551954e-02  6.62972219e-04 -1.18202996e-03
# ...

# %%
client.search(
    collection_name="Jurisgenie1",
    query_filter=models.Filter(

    ),
    query_vector=queryEmbeddings,
    limit=10,
)

# %%
from semantic_router.splitters import RollingWindowSplitter
from semantic_router.utils.logger import logger
from sentence_transformers import SentenceTransformer

logger.setLevel("WARNING")  # reduce logs from splitter

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
encoder = lambda texts: model.encode(data, convert_to_tensor=False)

splitter = RollingWindowSplitter(
    encoder=encoder,
    dynamic_threshold=True,
    min_split_tokens=100,
    max_split_tokens=500,
    window_size=2,
    plot_splits=True,  # set this to true to visualize chunking
    enable_statistics=True  # to print chunking stats
)

data=text="""The Hound of the Baskervilles is a classic Sherlock Holmes mystery by Arthur Conan Doyle. The story is set in the eerie moors of Devonshire, England, and follows the investigation of the legendary curse on the Baskerville family, which is said to involve a supernatural hound.

The tale begins with Dr. John Watson recounting a visit to Sherlock Holmes, where they discuss the mysterious death of Sir Charles Baskerville. Sir Charles was found dead on the moors, with an expression of terror on his face and footprints of a large hound nearby. Following his death, Sir Charles's heir, Sir Henry Baskerville, arrives from Canada, fearing for his life due to the family curse.

Holmes and Watson set out to uncover the truth. They investigate the moor, meet various characters—including the enigmatic housekeeper Mrs. Barrymore—and uncover clues that suggest a more earthly explanation for the haunting. The climax reveals that the supposed supernatural hound is, in fact, a trained dog used to scare Sir Charles and Sir Henry.

In the end, Holmes solves the mystery, revealing the true villain and clearing the Baskerville name, showcasing his brilliant deductive reasoning throughout. The novel blends elements of horror, mystery, and classic detective work, making it a cornerstone of the detective genre."""


splits = splitter(data)
print(splits)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# <ipython-input-8-fdf4c27f2db8>:18: UserWarning: Splitters are being deprecated. They have moved to their own package. Please migrate to the `semantic-chunkers` package. More information can be found at:
# https://github.com/aurelio-labs/semantic-chunkers
#   splitter = RollingWindowSplitter(
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-8-fdf4c27f2db8> in <cell line: 18>()
#      16
#      17 # Initialize the splitter with the correct structure for the encoder
# ...

# %% [markdown]
# **Active project starts**

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5a35c16a-05c8-452a-8f63-d8f63dab5c1a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a35c16a-05c8-452a-8f63-d8f63dab5c1a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install sentence_transformers

# %%
# !pip install qdrant-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.2/267.2 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from qdrant_client import QdrantClient, models
client = QdrantClient(
    url="https://e1d547b9-71ad-4d06-a9b2-ebae2c43f740.us-east4-0.gcp.cloud.qdrant.io:6333",
    api_key="xK64v33giC5SIp2iUTPFKp5LUpzBVmomi3Fb-go3_2HX6LwK-V7ahg",
)

#client = QdrantClient(url="http://localhost:6333")

#already created
client.create_collection(
    collection_name="JurisGenie",
    vectors_config=models.VectorParams(size=384, distance=models.Distance.COSINE),
)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# <ipython-input-5-20eefa00d934> in <cell line: 9>()
#       7 #client = QdrantClient(url="http://localhost:6333")
#       8
# ----> 9 client.create_collection(
#      10     collection_name="JurisGenie",
#      11     vectors_config=models.VectorParams(size=384, distance=models.Distance.COSINE),
#
# /usr/local/lib/python3.10/dist-packages/qdrant_client/qdrant_client.py in create_collection(self, collection_name, vectors_config, sparse_vectors_config, shard_number, sharding_method, replication_factor, write_consistency_factor, on_disk_payload, hnsw_config, optimizers_config, wal_config, quantization_config, init_from, timeout, **kwargs)
#    2239         assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
#    2240
# -> 2241         return self._client.create_collection(
# ...

# %%
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload
import os

# If modifying these SCOPES, delete the token.json file.
SCOPES = ['https://www.googleapis.com/auth/drive.file']

def authenticate():
    """Shows basic usage of the Google Drive API.
    Lists the names and IDs of the first 10 files the user has access to.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    return creds

creds=authenticate()

# %%
# !pip install langchain_text_splitters

# %% [markdown]
# since semantic chunking is not giving 100% accurate results we try document based chunking

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

def genEmbed(chunks):
    # Get embeddings for the chunks
    embeddings = model.encode(chunks)
    return list(embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import nltk

nltk.download('punkt')
def semantic_chunking(text, num_chunks):
    sentences = nltk.sent_tokenize(text)
    vectorizer = TfidfVectorizer()
    sentence_vectors = vectorizer.fit_transform(sentences)

    kmeans = KMeans(n_clusters=num_chunks)
    kmeans.fit(sentence_vectors)

    chunks = [[] for _ in range(num_chunks)]
    for i, label in enumerate(kmeans.labels_):
        chunks[label].append(sentences[i])

    return [' '.join(chunk) for chunk in chunks]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
import os
import io
from googleapiclient.http import MediaIoBaseDownload
import re
from langchain_text_splitters import RecursiveCharacterTextSplitter

import nltk


def recursiveChunk(doc):
    splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    separators=["\n\n"],
    is_separator_regex=False
    )



    chunks=splitter.split_text(doc)
    return chunks

# %%
def listAll(service):
    folder='1oa9kyK2Aeyf8c23-C2ttBaDpmBMwLUDM'
    query = f"'{folder}' in parents"
    results = service.files().list(q=query,pageSize=400, fields="files(id, name, mimeType)").execute()
    items = results.get('files', [])

    if not items:
        print('No files found.')
    else:
        print('Files:')

    return items

# %%
def downloadFile(service, file_id, file_name):
    request = service.files().get_media(fileId=file_id)
    fh = io.FileIO(file_name, 'wb')
    downloader = MediaIoBaseDownload(fh, request)

    done = False
    while not done:
        status, done = downloader.next_chunk()
        #print(f"Download {int(status.progress() * 100)}% complete.")

    #print(f"File {file_name} has been downloaded."

# %%
# !pip install qdrant-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.4/266.4 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 37.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 59.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 19.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
# ...

# %%
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
import os
import io
from googleapiclient.http import MediaIoBaseDownload
from qdrant_client import QdrantClient, models
import logging


logging.basicConfig(level=logging.INFO)

client = QdrantClient(
    url="https://e1d547b9-71ad-4d06-a9b2-ebae2c43f740.us-east4-0.gcp.cloud.qdrant.io:6333",
    api_key="xK64v33giC5SIp2iUTPFKp5LUpzBVmomi3Fb-go3_2HX6LwK-V7ahg",
)


def downloadFilesToQdrant():
    creds =authenticate()

    # Build the Drive API client
    service = build('drive', 'v3', credentials=creds)
    files = listAll(service)
    print(len(files))
    count=0
    for file in files:
        if file['mimeType'] == 'text/plain':
            file_id = file['id']
            file_name = file['name']
            #print(file_name)
            downloadFile(service, file_id, file_name)
            with open(file_name, 'r', encoding='utf-8') as fls:
                data=fls.read()
            link=data[0:data.index('\n')]
            print(link)

            '''print(len(temp))
            for i in temp:
              print(i,"CHUNK---------------------------------------------------------------------------------\n")'''


            #print(t[0][0:t[0].index('2024')+4])

            temp=semantic_chunking(data,15)
            print(len(temp))
            for i in range(len(temp)):
              count=count+1
              embed=genEmbed(temp[i])
              print(temp[i])
              print(len(embed))
              print(embed)
              print("------------------------------------------------------------")

              response=client.upsert(
                    collection_name="JurisGenie",
                    wait=True,
                    points=[models.PointStruct(
                            id=count,
                            payload={
                                "link": link,
                                "chunk":temp[i],
                                },

                            vector=embed,
                            ),
                    ])
              print("Hi", logging.info(f"Upsert response for id {count}: {response}"))
            fls.close()

# %%
downloadFilesToQdrant()
# Out:
# Streaming output truncated to the last 5000 lines.
#
# could be made or action taken under the very same Entry. Further reference could also be made to theFood Safety
#
# and Standards Act, 2006(“FSSA, 2006”) which has been enacted
#
# pursuant to Entry 52 – List I where the Parliament by a
#
# declaration made underSection 2of the said Act has declared
#
# that it is expedient in the public interest that the Union should
#
# take under its control the food industry. Page 209 of 241would apply in the matter of production, supply and distribution
#
# of goods or trade and commerce of the products of any industry
#
# or any other specific Entry in List II, as the case may be.22. Thus, insofar as “Fermentation Industries” (other than
#
# potable alcohol) is concerned, both alcohol and other products of
#
# “Fermentation Industries” being a scheduled industry under the
#
# IDRA passed under Entry 52 – List I it would clearly be within
#
# ...

# %%
import os

# Create a templates folder if it doesn't already exist
os.makedirs("templates", exist_ok=True)

# Write a sample HTML file in the templates folder
with open("templates/index.html", "w") as f:
    f.write("""
    <!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>JurisGenie</title>

    <!-- Link to Font Awesome CSS for icons -->
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.0.0-beta3/css/all.min.css">

    <style>
        body {
            font-family: 'Arial', sans-serif;
            margin: 20px;
            padding: 0;
            background-color: #121212; /* Dark background */
            color: #e0e0e0; /* Light text color */
        }

        h1 {
            text-align: center;
            font-size: 3rem;
            color: #ffffff;
            letter-spacing: 2px;
            margin-bottom: 10px;
        }

        h2 {
            text-align: center;
            font-size: 1.5rem;
            color: #28a745; /* Vibrant green color */
            margin-bottom: 30px;
        }

        .search-container {
            display: flex;
            justify-content: center;
            align-items: center;
            position: relative;
            margin-bottom: 20px;
            left: 20px;
        }

        input[type="text"] {
            width: 400px;
            padding: 12px 20px;
            border-radius: 50px;
            border: 1px solid #444; /* Darker border for modern look */
            background-color: #1e1e1e; /* Dark input field */
            color: #e0e0e0; /* Light text */
            font-size: 16px;
            padding-right: 40px;
            transition: all 0.3s ease;
        }

        input[type="text"]:focus {
            outline: none;
            border-color: #28a745; /* Green border on focus */
            background-color: #292929; /* Slightly lighter input background */
        }



        button.search-icon {
            position: relative;
            background: none;
            border: none;
            top: 4px;
            right: 4px;
            color: #28a745;
            font-size: 20px;
            cursor: pointer;
            transition: color 0.3s ease;
        }

        button.search-icon:hover {
            color: #42e260; /* Brighter hover color */
        }

        .suggestions-list {
            position: absolute;
            top: 55px;
            width: 400px;
            background-color: #1e1e1e; /* Dark background for suggestions */
            border: 1px solid #333; /* Darker border */
            border-radius: 5px;
            max-height: 200px;
            overflow-y: auto;
            z-index: 1000;
            display: none;
        }

        .suggestions-list li {
            padding: 10px;
            color: #e0e0e0; /* Light text */
            cursor: pointer;
            list-style-type: none;
            border-bottom: 1px solid #333;
            transition: background 0.3s ease;
        }

        .suggestions-list li:hover {
            background-color: #333; /* Hover color for suggestions */
        }

        .results {
            margin-top: 30px;
            text-align: center;
        }

        .results ul {
            list-style-type: none;
            padding: 0;
        }

        .results ul li {
            padding: 15px;
            border-bottom: 1px solid #333;
            font-size: 1.1rem;
            color: #ffffff;
        }

        .results p {
            font-size: 1.2rem;
            color: #888;
        }

        /* Scrollbar styling for modern look */
        ::-webkit-scrollbar {
            width: 8px;
        }

        ::-webkit-scrollbar-thumb {
            background: #444;
            border-radius: 4px;
        }

        ::-webkit-scrollbar-thumb:hover {
            background: #555;
        }
    </style>
</head>
<body>

    <h1>JurisGenie</h1>
    <h2>you just got lawyered!</h2>

    <div class="search-container">
        <!-- Search form that submits to the backend -->
        <form method="POST" action="/">
            <input type="text" id="searchBar" name="query" placeholder="Search" oninput="showSuggestions()" onkeydown="handleKeyDown(event)" required>
            <button type="submit" class="search-icon"><i class="fas fa-search"></i></button> <!-- Transparent button with search icon -->
            <ul id="suggestionsList" class="suggestions-list"></ul> <!-- Suggestions list -->
        </form>
    </div>

    <!-- Display the results using Jinja2 -->
    <div class="results">
        {% if results %}
            <h2>Top Results for "{{ query }}":</h2>
            <ul>
                {% for result in results %}
                    <li>{{ result[0] }} <a href="{{ result[1] }}" style="color: blue;">{{ result[1] }}</a></li>
                {% endfor %}
            </ul>
        {% elif query %}
            <p>No results found for "{{ query }}"</p>
        {% endif %}
    </div>

    <script>
        const searchHistory = [];

        function handleKeyDown(event) {
            // Check if the Enter key (key code 13) is pressed
            if (event.key === "Enter") {
                event.preventDefault();
                performSearch();
            }
        }

        function performSearch() {
            const searchInput = document.getElementById('searchBar').value;

            // If the search input is not empty, add it to the search history
            if (searchInput) {
                searchHistory.unshift(searchInput);  // Add to the beginning of the array

                // Limit the search history to the last 5 unique searches
                if (searchHistory.length > 5) {
                    searchHistory.pop();  // Remove the oldest search if more than 5
                }

                // Clear the search bar
                document.getElementById('searchBar').value = '';

                // Hide suggestions after search
                document.getElementById('suggestionsList').style.display = 'none';
            }
        }

        function showSuggestions() {
            const input = document.getElementById('searchBar').value.toLowerCase();
            const suggestionsList = document.getElementById('suggestionsList');

            // Use a Set to ensure unique suggestions
            const uniqueSuggestions = new Set(searchHistory);

            // Filter the unique suggestions based on user input
            const filteredSuggestions = Array.from(uniqueSuggestions).filter(term => term.toLowerCase().includes(input));

            // Clear the previous suggestions
            suggestionsList.innerHTML = '';

            if (input && filteredSuggestions.length > 0) {
                // Show suggestions
                filteredSuggestions.forEach(suggestion => {
                    const li = document.createElement('li');
                    li.textContent = suggestion;

                    // When clicking a suggestion, fill the search bar with the suggestion and hide the list
                    li.onclick = () => {
                        document.getElementById('searchBar').value = suggestion;
                        suggestionsList.style.display = 'none';
                    };

                    suggestionsList.appendChild(li);
                });

                // Display the suggestions list
                suggestionsList.style.display = 'block';
            } else {
                // Hide suggestions if no matching history or no input
                suggestionsList.style.display = 'none';
            }
        }
    </script>

</body>
</html>

    """)

# %%
# !pip install flask
# !pip install flask_ngrok
# !pip install pyngrok

# !ngrok authtoken 2nv8KuqjjrPvDJTtctzDwwv0Rcw_4pofN2H3ANTxJ2ckjGFws
# Out:
# ...
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from flask import Flask, render_template, request
from flask_ngrok import run_with_ngrok
from pyngrok import ngrok
from qdrant_client import QdrantClient, models

client = QdrantClient(
    url="https://e1d547b9-71ad-4d06-a9b2-ebae2c43f740.us-east4-0.gcp.cloud.qdrant.io:6333",
    api_key="xK64v33giC5SIp2iUTPFKp5LUpzBVmomi3Fb-go3_2HX6LwK-V7ahg",
)




app = Flask(__name__)
ngrok.set_auth_token("2nv8KuqjjrPvDJTtctzDwwv0Rcw_4pofN2H3ANTxJ2ckjGFws")
public_url = ngrok.connect(5000)


run_with_ngrok(app)


def retrieve(query):
  queryEmbed=genEmbed(query)
  unique_results = []
  seen_links = set()


  results = client.search(
    collection_name="JurisGenie",
    query_vector=queryEmbed,
    limit=150,
    score_threshold=0.5)





      # Collect unique results based on `link`
  for result in results:
    link = result.payload.get("link")
    if link and link not in seen_links:
      unique_results.append(result)
      seen_links.add(link)
      if len(unique_results) == 10:
        break

  print("bbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb",unique_results)

  results=[]
  for i in range(len(unique_results)):
        results.append([f"Document {i+1}: ",unique_results[i].payload['link']])
  return results




'''def retrieve(query):
    queryEmbed=genEmbed(query)
    result = client.search(
    collection_name="JurisGenie",
    query_vector=queryEmbed,
    limit=10)
    #print(result[0].payload['link'])
    payload_values = result[0].payload['link']
    print('aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa',len(result))

    results=[]
    for i in range(len(result)):
        results.append([f"Document {i+1}: ",result[i].payload['link']])

    return results
'''


@app.route("/", methods=["GET", "POST"])
def search():
    results=[]
    if request.method == "POST":
        query = request.form["query"]

        results = retrieve(query)
        print("------------------------",results)

        return render_template('index.html',query=query,results=results)

    return render_template('index.html',query=None,results=None)

if __name__ == "__main__":
    app.run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-2f6d5cee6d38> in <cell line: 0>()
#       2 from flask_ngrok import run_with_ngrok
#       3 from pyngrok import ngrok
# ----> 4 from qdrant_client import QdrantClient, models
#       5
#       6 client = QdrantClient(
#
# ModuleNotFoundError: No module named 'qdrant_client'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
unique_results = []
seen_links = set()


    # Adjust the number of points returned in each iteration as necessary
search_results = client.search(
    collection_name="JurisGenie",
    query_vector=query_vector,
    score_threshold="0.4"
    limit=150,  # number of top results you want to retrieve
)

    # Collect unique results based on `link`
for result in search_results:
    link = result.payload.get("link")
    if link and link not in seen_links:
          unique_results.append(result)
          seen_links.add(link)

    if len(unique_results) == 10:
          break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-7f69386e53c7> in <cell line: 4>()
#       6     results = client.search(
#       7         collection_name="your_collection_name",
# ----> 8         query_vector=your_query_vector,
#       9         top=10,  # Adjust as needed to get sufficient results for filtering
#      10         filter={
#
# NameError: name 'your_query_vector' is not defined
